# %% [markdown]
# <a href="https://colab.research.google.com/github/AbrarAmiya/Data-Structure/blob/main/Implementing_a_2D_Electronic_Text_Billboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("The user have to input one upper case letter")
txt1=input("")
if len(txt1)>10:
  print("Invalid text size:")
txt2=input("")
if len(txt1)>10:
  print("Invalid text size:")


array=[[0]*10,[1]*10]

for i in range(len(txt1)):
  array[0][i]=txt1[i]
for i in range(len(txt2)):
  array[1][i]=txt2[i]

start_1=0
for i in range(len(array[0])):

  if 65<=ord(array[0][i])<=90:
    start_1=array[0][i]


start_2=0
for i in range(len(array[1])):

  if 65<=ord(array[1][i])<=90:
    start_2=array[1][i]

print("Start for the first row:",start_1)
print("Start for the second row:",start_2)

size_1=0

for i in range(len(array[0])):
  if array[0][i]!=0:
    size_1+=1

size_2=0

for i in range(len(array[1])):
  if array[1][i]!=0:
    size_2+=1

print("Size of first row:",size_1)
print("Size of second row:",size_2)

idx1=0
for i in range(len(array[0])):
  if array[0][i]==start_1:
    idx1=i

idx2=0
for i in range(len(array[1])):
  if array[1][i]==start_2:
    idx2=i
  
print("index of first:",idx1,"index of second:",idx2)  




class CirArray:
  def __init__(self,array,start_1,start_2,size_1,size_2,idx1,idx2):
    self.start1=start_1
    self.start2=start_2
    self.size1=size_1
    self.size2=size_2
    self.idx1=idx1
    self.idx2=idx2
    self.cir=[[0]*10,[1]*10]

    for i in range(len(array[0])):
      self.cir[0][i]=array[0][idx1]
      idx1=(idx1+1)%len(self.cir[0])

    for i in range(len(array[1])):
      self.cir[1][i]=array[1][idx2]
      idx2=(idx2+1)%len(self.cir[1])

  def printARR(self):
    return self.cir

  def left(self,k):
    i=((self.idx1)+k)%len(self.cir[0])
    count=0
    while count<self.size1:
      print(self.cir[0][i],end=',')
      i=(i+k)%len(self.cir[0])

      count+=1
    
  def right(self,k):
    i=((self.idx2)-k)%len(self.cir[1])
    count=0
    while count<self.size2:
      print(self.cir[1][i],end=' ')
      i=(i+k)%len(self.cir[1])

      count+=k
  
 

array=CirArray(array,start_1,start_2,size_1,size_2,idx1,idx2)
print(array.printARR())
print(array.left(1))
print(array.right(1))
# Out:
# The user have to input one upper case letter
# left2Right
# right2Left
# Start for the first row: R
# Start for the second row: L
# Size of first row: 10
# Size of second row: 10
# index of first: 5 index of second: 6
# [['R', 'i', 'g', 'h', 't', 'l', 'e', 'f', 't', '2'], ['L', 'e', 'f', 't', 'r', 'i', 'g', 'h', 't', '2']]
# e,f,t,2,R,i,g,h,t,l,None
# i g h t 2 L e f t r None

# %%
#right2Left
#Right2left






def left(arr,k):
  idx=0
  
  start=(idx+k)%len(arr)
  count=0
  while count<len(arr):
    print(arr[start],end=' ')
    start=(start+1)%len(arr)
    count+=1
  print()

def right(arr,k):
  idx=0
  cnt=0
  end=(idx-k)%len(arr)
  while cnt<len(arr):
    print(arr[end],end=' ')
    end=(end+1)%len(arr)
    cnt+=1
  print()





arr=[1,2,3,4,5]
k=1

print("the left")
left(arr,k)
print("right")
right(arr,k)
print("--------------")


#cont=1
#while cont<10:
#  left(arr,k)
#  cont+=1
#  k=cont
a=0
count=0
while True:
  a=(input("Enter: "))
  if a=='Q' or a=="q":
    break
  print("Left shift")
  left(arr,k)
  print("Right shift")
  right(arr,k)
  k+=1
# Out:
# the left
# 2 3 4 5 1
# right
# 5 1 2 3 4
# --------------
# Enter: e
# Left shift
# 2 3 4 5 1
# Right shift
# 5 1 2 3 4
# Enter: r
# Left shift
# 3 4 5 1 2
# Right shift
# 4 5 1 2 3
# Enter: q

# %%
print("The user have to input one upper case letter")
txt1=input("")
if len(txt1)>10:
  print("Invalid text size:")
txt2=input("")
if len(txt1)>10:
  print("Invalid text size:")


array=[[0]*10,[1]*10]

for i in range(len(txt1)):
  array[0][i]=txt1[i]
for i in range(len(txt2)):
  array[1][i]=txt2[i]

print("The Array",array)
print()
print(array[0])
print(array[1])
print()

start_1=0
for i in range(len(array[0])):

  if 65<=ord(array[0][i])<=90:
    start_1=array[0][i]


start_2=0
for i in range(len(array[1])):

  if 65<=ord(array[1][i])<=90:
    start_2=array[1][i]

print("Start for the first row:",start_1)
print("Start for the second row:",start_2)

size_1=0

for i in range(len(array[0])):
  if array[0][i]!=0:
    size_1+=1

size_2=0

for i in range(len(array[1])):
  if array[1][i]!=0:
    size_2+=1
print()
print("Size of first row:",size_1)
print("Size of second row:",size_2)

idx1=0
for i in range(len(array[0])):
  if array[0][i]==start_1:
    idx1=i

idx2=0
for i in range(len(array[1])):
  if array[1][i]==start_2:
    idx2=i
print() 
print("index of first:",idx1)
print("index of second:",idx2)
print()

#Calling Functions
def left(array,k,idx,size):
  i=(idx+k)%len(array[0])
  count=0
  while count<size:
    print(array[0][i],end=' ')
    i=(i+1)%len(array[0])
    count+=1

def right(array,k,idx,size):
  i=(idx-k)%len(array[1])
  count=0
  while count<size:
    print(array[1][i],end=' ')
    i=(i+1)%len(array[0])
    count+=1



#left(array,1,idx1,size_1)
print()
#right(array,1,idx2,size_2)

print("----------------------------------")
print()
#the loop
k=1


#cont=1
#while cont<10:
#  left(arr,k)
#  cont+=1
#  k=cont
a=0
count=0
while True:
  a=(input("Enter: "))
  if a=='Q' or a=="q":
    break
  print("Left shift")
  left(array,k,idx1,size_1)
  print()
  print("Right shift")
  right(array,k,idx2,size_2)
  k+=1
  print()
# Out:
# The user have to input one upper case letter
# right2Left
# Right2left
# The Array [['r', 'i', 'g', 'h', 't', '2', 'L', 'e', 'f', 't'], ['R', 'i', 'g', 'h', 't', '2', 'l', 'e', 'f', 't']]
#
# ['r', 'i', 'g', 'h', 't', '2', 'L', 'e', 'f', 't']
# ['R', 'i', 'g', 'h', 't', '2', 'l', 'e', 'f', 't']
#
# Start for the first row: L
# Start for the second row: R
#
# Size of first row: 10
# Size of second row: 10
#
# index of first: 6
# index of second: 0
#
#
# ----------------------------------
#
# Enter: e
# Left shift
# e f t r i g h t 2 L
# Right shift
# t R i g h t 2 l e f
# Enter: t
# Left shift
# f t r i g h t 2 L e
# Right shift
# f t R i g h t 2 l e
# Enter: h
# Left shift
# t r i g h t 2 L e f
# Right shift
# e f t R i g h t 2 l
# Enter: j
# Left shift
# r i g h t 2 L e f t
# Right shift
# l e f t R i g h t 2
# Enter: f
# Left shift
# i g h t 2 L e f t r
# Right shift
# 2 l e f t R i g h t
# Enter: q
